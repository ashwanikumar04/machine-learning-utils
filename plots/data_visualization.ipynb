# %%
import pandas as pd
import numpy as np

# %%
car_loans = pd.read_csv('data/car_financing.csv')
car_loans.head(1)
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93           484.3
#
#    New Balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna

# %%
car_loans.dtypes
# Out:
# Month                 int64
# Starting Balance    float64
# Repayment           float64
# Interest Paid       float64
# Principal Paid      float64
# New Balance         float64
# term                  int64
# interest_rate       float64
# car_type             object
# dtype: object

# %%
car_loans.shape
# Out:
# (408, 9)

# %%
car_loans['car_type'].value_counts()
# Out:
# VW Golf R         144
# Toyota Sienna     120
# Toyota Carolla    111
# Toyota Corolla     33
# Name: car_type, dtype: int64

# %%
car_loans = car_loans.rename(columns={'Month':'month','Starting Balance':'starting_balance','Repayment':'repayment'
                                      ,'Interest Paid':'interest_paid','Principal Paid':'principal_paid','New Balance':'new_balance' })

# %%
car_loans.head(1)
# Out:
#    month  starting_balance  repayment  interest_paid  principal_paid  \
# 0      1          34689.96     687.23         202.93           484.3
#
#    new_balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna

# %%
car_loans = car_loans.drop(columns=['term','repayment'])

# %%
car_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 7 columns):
# month               408 non-null int64
# starting_balance    408 non-null float64
# interest_paid       408 non-null float64
# principal_paid      408 non-null float64
# new_balance         408 non-null float64
# interest_rate       408 non-null float64
# car_type            408 non-null object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 22.4+ KB

# %%
car_loans.isna().sum()
# Out:
# month               0
# starting_balance    0
# interest_paid       0
# principal_paid      0
# new_balance         0
# interest_rate       0
# car_type            0
# dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car_loans = car_loans.loc[:59]

# %%
car_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
# month               60 non-null int64
# starting_balance    60 non-null float64
# interest_paid       60 non-null float64
# principal_paid      60 non-null float64
# new_balance         60 non-null float64
# interest_rate       60 non-null float64
# car_type            60 non-null object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.4+ KB

# %%
month_number = car_loans.loc[:,'month'].values
interest_paid = car_loans.loc[:,'interest_paid'].values
principal_paid = car_loans.loc[:,'principal_paid'].values

# %%
plt.plot(month_number,interest_paid)
plt.plot(month_number,principal_paid)

# %%
plt.style.available
# Out:
# ['seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-whitegrid',
#  'classic',
#  '_classic_test',
#  'fast',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'seaborn-bright',
#  'seaborn-pastel',
#  'grayscale',
#  'seaborn-notebook',
#  'ggplot',
#  'seaborn-colorblind',
#  'seaborn-muted',
#  'seaborn',
#  'Solarize_Light2',
#  'seaborn-paper',
#  'bmh',
#  'tableau-colorblind10',
#  'seaborn-white',
#  'dark_background',
#  'seaborn-poster',
#  'seaborn-deep']

# %%
plt.style.use('classic')
plt.plot(month_number,interest_paid)
plt.plot(month_number,principal_paid)

# %%
plt.style.use('seaborn')
plt.plot(month_number,interest_paid)
plt.plot(month_number,principal_paid)

# %% [markdown]
# # Matlab Style

# %%
plt.style.use('seaborn')
plt.plot(month_number,interest_paid,c='k')
plt.plot(month_number,principal_paid,c='b')
plt.xlabel('Month',fontsize=15)
plt.ylabel('Dollars',fontsize=15)
plt.title('Principal and interest paid per month', fontsize=22)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.tight_layout()

# %% [markdown]
# # Object oriented Style

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
axes.plot(month_number, interest_paid, c='k')
axes.plot(month_number, principal_paid, c='b')
axes.set_xlabel('Month',fontsize=15)
axes.set_ylabel('Dollars',fontsize=15)
axes.set_title('Principal and interest paid per month',fontsize=22)
axes.tick_params(axis='x',labelsize=15)
axes.tick_params(axis='y',labelsize=15)
fig.tight_layout()

# %% [markdown]
# # Combination

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
plt.plot(month_number, interest_paid, c='k')
axes.plot(month_number, principal_paid, c='b')

# %%
cancer_df = pd.read_csv('data/wisconsinBreastCancer.csv')
cancer_df.head(1)
# Out:
#        id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302         M        17.99         10.38           122.8     1001.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.1184            0.2776          0.3001               0.1471
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33            184.6      2019.0            0.1622
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
#
#    fractal_dimension_worst  Unnamed: 32
# 0                   0.1189          NaN
#
# [1 rows x 33 columns]

# %%
cancer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
cancer_df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
cancer_df.boxplot(column='area_mean', by='diagnosis')

# %%
sns.boxplot(x='diagnosis', y='area_mean', data=cancer_df)

# %% [markdown]
# ## Visualizing Stock Trends by Using a Line Plot

# %%
google = pd.read_csv('data/GOOGL_data.csv')
facebook = pd.read_csv('data/FB_data.csv')
apple = pd.read_csv('data/AAPL_data.csv')
amazon = pd.read_csv('data/AMZN_data.csv')
microsoft = pd.read_csv('data/MSFT_data.csv')

google.head(1)
# Out:
#          date      open      high       low     close   volume   Name
# 0  2013-02-08  390.4551  393.7283  390.1698  393.0777  6031199  GOOGL

# %%
# Create figure
plt.figure(figsize=(16, 8), dpi=300)
# Plot data
plt.plot('date', 'close', data=google, label='Google')
plt.plot('date', 'close', data=facebook, label='Facebook')
plt.plot('date', 'close', data=apple, label='Apple')
plt.plot('date', 'close', data=amazon, label='Amazon')
plt.plot('date', 'close', data=microsoft, label='Microsoft')
# Specify ticks for x- and y-axis
plt.xticks(np.arange(0, 1260, 40), rotation=70)
plt.yticks(np.arange(0, 1450, 100))
# Add title and label for y-axis
plt.title('Stock trend', fontsize=16)
plt.ylabel('Closing price in $', fontsize=14)
# Add grid
plt.grid()
# Add legend
plt.legend()
# Show plot
plt.show()

# %% [markdown]
# ## Creating a Bar Plot for Movie Comparison

# %%
# Load dataset
movie_scores = pd.read_csv('data/movie_scores.csv')
movie_scores.head(1)
# Out:
#    Unnamed: 0          MovieTitle  Tomatometer  AudienceScore
# 0           0  The Shape of Water           91             73

# %%
# Create figure
plt.figure(figsize=(10, 5), dpi=300)
# Create bar plot
pos = np.arange(len(movie_scores['MovieTitle']))
width = 0.3
plt.bar(pos - width / 2, movie_scores['Tomatometer'], width, label='Tomatometer')
plt.bar(pos + width / 2, movie_scores['AudienceScore'], width, label='Audience Score')
# Specify ticks
plt.xticks(pos, rotation=10)
plt.yticks(np.arange(0, 101, 20))
# Get current Axes for setting tick labels and horizontal grid
ax = plt.gca()
# Set tick labels
ax.set_xticklabels(movie_scores['MovieTitle'])
ax.set_yticklabels(['0%', '20%', '40%', '60%', '80%', '100%'])
# Add minor ticks for y-axis in the interval of 5
ax.set_yticks(np.arange(0, 100, 5), minor=True)
# Add major horizontal grid with solid lines
ax.yaxis.grid(which='major')
# Add minor horizontal grid with dashed lines
ax.yaxis.grid(which='minor', linestyle='--')
# Add title
plt.title('Movie comparison')
# Add legend
plt.legend()
# Show plot
plt.show()

# %% [markdown]
# ## Creating a Pie Chart for Water Usage

# %%
# Load dataset
water_usage = pd.read_csv('data/water_usage.csv')
water_usage.head(1)
# Out:
#    Unnamed: 0 Usage  Percentage
# 0           0  Leak          12

# %%
# Create figure
plt.figure(figsize=(4, 4), dpi=300)
# Create pie plot
plt.pie('Percentage', explode=(0, 0, 0.1, 0, 0, 0), labels='Usage', data=water_usage, autopct='%.0f%%')
# Add title
plt.title('Water usage')
# Show plot
plt.show()

# %% [markdown]
# ## Creating a Stacked Bar Plot to Visualize Restaurant Performance

# %%
bills = sns.load_dataset('tips')
bills.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %% [markdown]
# Use the given dataset and create a matrix where the elements contain the sum of the total bills for each day and smoking/non-smoking person.

# %%
days = ['Thur', 'Fri', 'Sat', 'Sun']
days_range = np.arange(len(days))
smoker = ['Yes', 'No']

bills_by_days = [bills[bills['day'] == day] for day in days]
bills_by_days_smoker = [[bills_by_days[day][bills_by_days[day]['smoker'] == s] for s in smoker] for day in days_range]
total_by_days_smoker = [[bills_by_days_smoker[day][s]['total_bill'].sum() for s in range(len(smoker))] for day in days_range]
totals = np.asarray(total_by_days_smoker)

# %% [markdown]
# Create a stacked bar plot, stacking the summed smoking and non-smoking total bills separated for each day. Add a legend, labels, and a title.

# %%
# Create figure
plt.figure(figsize=(10, 5), dpi=300)
# Create stacked bar plot
plt.bar(days_range, totals[:, 0], label='Smoker')
plt.bar(days_range, totals[:, 1], bottom=totals[:, 0], label='Non-smoker')
# Add legend
plt.legend()
# Add labels and title
plt.xticks(days_range)
ax = plt.gca()
ax.set_xticklabels(days)
ax.yaxis.grid()
plt.ylabel('Daily total sales in $')
plt.title('Restaurant performance')
# Show plot
plt.show()

# %% [markdown]
# ## Comparing Smartphone Sales Units Using a Stacked Area Chart

# %%
# Load dataset
sales = pd.read_csv('data/smartphone_sales.csv')
sales.head(1)
# Out:
#    Unnamed: 0 Quarter  Apple  Samsung  Huawei  Xiaomi   OPPO
# 0           0    3Q16  43001    71734   32490   14926  24591

# %%
# Create figure
plt.figure(figsize=(10, 6), dpi=300)
# Create stacked area chart
labels = sales.columns[1:]
plt.stackplot('Quarter', 'Apple', 'Samsung', 'Huawei', 'Xiaomi', 'OPPO', data=sales, labels=labels)
# Add legend
plt.legend()
# Add labels and title
plt.xlabel('Quarters')
plt.ylabel('Sales units in thousands')
plt.title('Smartphone sales units')
# Show plot
plt.show()

# %% [markdown]
# ## Using a Scatter Plot to Visualize Correlation Between Various Animals

# %%
# Load dataset
animals = pd.read_csv('./data/anage_data.csv')
animals.head(1)
# Out:
#    Unnamed: 0  HAGRID   Kingdom      Phylum         Class        Order  \
# 0           0       3  Animalia  Arthropoda  Branchiopoda  Diplostraca
#
#        Family    Genus    Species Common name  ...  Growth rate (1/days)  \
# 0  Daphniidae  Daphnia  pulicaria     Daphnia  ...                   NaN
#
#    Maximum longevity (yrs)  Specimen origin  Sample size  Data quality  \
# 0                     0.19          unknown       medium    acceptable
#
#    IMR (per yr)  MRDT (yrs)  Metabolic rate (W)  Body mass (g)  \
# 0           NaN         NaN                 NaN            NaN
#
#    Temperature (K)
# 0              NaN
#
# [1 rows x 30 columns]

# %% [markdown]
# The given dataset is not complete. Filter the data so you end up with samples containing a body mass and a maximum longevity. Sort the data according to the animal class.

# %%
longevity = 'Maximum longevity (yrs)'
mass = 'Body mass (g)'
animals = animals[np.isfinite(animals[longevity]) & np.isfinite(animals[mass])]
# Sort according to class
amphibia = animals[animals['Class'] == 'Amphibia']
aves = animals[animals['Class'] == 'Aves']
mammalia = animals[animals['Class'] == 'Mammalia']
reptilia = animals[animals['Class'] == 'Reptilia']

# %%
# Create figure
plt.figure(figsize=(10, 6), dpi=300)
# Create scatter plot
plt.scatter(amphibia[mass], amphibia[longevity], label='Amphibia',color='red')
plt.scatter(aves[mass], aves[longevity], label='Aves',color='blue')
plt.scatter(mammalia[mass], mammalia[longevity], label='Mammalia',color='green')
plt.scatter(reptilia[mass], reptilia[longevity], label='Reptilia',color='black')
# Add legend
plt.legend()
# Log scale
ax = plt.gca()
ax.set_xscale('log')
ax.set_yscale('log')
# Add labels
plt.xlabel('Body mass in grams')
plt.ylabel('Maximum longevity in years')
# Show plot
plt.show()

# %% [markdown]
# ## Using Heatmaps to Find Patterns in Flight Passengers' Data

# %%
flight_details = pd.read_csv("data/flight_details.csv")
flight_details.head(1)
# Out:
#    Years   Months  Passengers
# 0   2001  January         112

# %%
flight_details = flight_details.pivot("Months", "Years", "Passengers")
flight_details.head(1)
# Out:
# Years   2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  2012
# Months
# April    129   135   163   181   235   227   269   313   348   348   396   461

# %%
sns.set()
plt.figure(dpi=150)
sns.heatmap(flight_details, cmap=sns.light_palette("orange", as_cmap=True, reverse=True))
plt.title("Flight Passengers from 2001 to 2012")
#plt.xlabel("Years")
#plt.ylabel("Months")
plt.show()

# %% [markdown]
# ## Top 30 YouTube Channels

# %%
youtube = pd.read_csv("data/youtube.csv")
youtube.head(1)
# Out:
#     channels  subs  views
# 0  PewDiePie  83.1  20329

# %%
channels = youtube[youtube.columns[0]].tolist()

# %%
print(channels)
# Out:
# ['PewDiePie', 'T-Series', '5-Minute Crafts', 'Canal KondZilla', 'Justin Bieber', 'SET India', 'WWE', 'Dude Perfect', 'HolaSoyGerman', 'Ed Sheeran', 'EminemMusic', 'Badabun', 'Cocomelon - Nursery Rhymes', 'whinderssonnunes', 'JustinBieberVEVO', 'elrubiusOMG', 'JuegaGerman', 'Taylor Swift', 'Katy Perry', 'Fernanfloo', 'Ariana Grande', 'Rihanna', 'TheEllenShow', 'Zee Music Company', 'Felipe Neto', 'One Direction', 'YouTube Spotlight', 'TaylorSwiftVEVO', 'EminemVEVO', 'KatyPerryVEVO']

# %%
subs = youtube[youtube.columns[1]].tolist()

# %%
views = youtube[youtube.columns[2]].tolist()

# %%
print(subs)
print()
print(views)
# Out:
# [83.1, 82.9, 48.0, 46.1, 43.1, 40.7, 39.2, 38.7, 36.9, 36.8, 35.8, 35.0, 34.8, 34.2, 33.9, 33.5, 32.7, 32.2, 32.1, 31.8, 31.6, 31.2, 30.6, 30.3, 30.2, 28.7, 28.0, 27.8, 26.4, 26.4]
#
# [20329, 61057, 12061, 22878, 601, 28573, 29886, 7168, 3790, 15926, 637, 19388, 9737, 2801, 18375, 7313, 8730, 233, 357, 706, 6755, 59, 14847, 14614, 5938, 330, 1833, 16161, 12548, 16890]

# %%
youtube = pd.DataFrame({'YouTube Channels': channels + channels, 'Subscribers in millions': subs + views, 
                     'Type': ['Subscribers'] * len(subs) + ['Views'] * len(views)})

# %%
youtube.head(5)
# Out:
#   YouTube Channels  Subscribers in millions         Type
# 0        PewDiePie                     83.1  Subscribers
# 1         T-Series                     82.9  Subscribers
# 2  5-Minute Crafts                     48.0  Subscribers
# 3  Canal KondZilla                     46.1  Subscribers
# 4    Justin Bieber                     43.1  Subscribers

# %%
sns.set()
g = sns.FacetGrid(youtube, col='Type', hue='Type', sharex=False, height=8)
g.map(sns.barplot, 'Subscribers in millions', 'YouTube Channels')
plt.show()
# Out:
# /Users/akumar/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
planets = sns.load_dataset('planets')
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
with sns.axes_style('white'):
    g = sns.catplot("year", data=planets, aspect=2,
                       kind="count", color='steelblue')
    g.set_xticklabels(step=5)

# %%
with sns.axes_style('white'):
    g = sns.factorplot("year", data=planets, aspect=4.0, kind='count',
                       hue='method', order=range(2001, 2015))
    g.set_ylabels('Number of Planets Discovered')
# Out:
# /Users/akumar/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# # Plot cheat sheet

# %% [markdown]
# ![Cheat sheet](images/visualization_Cheatsheet.png)
